# %% [markdown]
# <a href="https://colab.research.google.com/github/ae200/Academical-portfolio/blob/master/FirstProTensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([
    # Define the input shape
    tf.keras.Input(shape=(1,)),
    # Add a dense layer
    tf.keras.layers.Dense(units=1)
])

# %%
# Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Declare model inputs and outputs for training
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# Train the model
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 4.5909
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 3.7831
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3.1440
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 2.6378
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 2.2361
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.9168
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.6624
# Epoch 8/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.4590
# Epoch 9/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 1.2959
# Epoch 10/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.1646
# Epoch 11/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.0582
# Epoch 12/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.9717
# Epoch 13/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.9007
# Epoch 14/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.8421
# Epoch 15/500
# ...

# %%
# Predict the best value for y
model.predict(np.array([10.0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# array([[18.984497]], dtype=float32)
